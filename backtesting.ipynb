# %%
# all the imports here
from alfa import stock_check_weekly  # ignore underline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import talib as tb  
import yfinance as yf
import time

# %%
# testing

data_raw = yf.download(tickers="RELIANCE.NS",period = "4000d" , interval = "1D")

'''
for intradday and medium swing trading use the following formula
 data_raw = yf.download(tickers=company_name,period = "10d",interval = "30m")
'''
alfa = data_raw.head(100)
plt.plot(alfa['Close'])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# intradya and swing trading
data_raw = yf.download(tickers="APOLLOHOSP.NS",period = "60d",interval = "30m")
data_raw.info()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 780 entries, 2022-04-07 09:00:00+05:30 to 2022-07-04 15:00:00+05:30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       780 non-null    float64
#  1   High       780 non-null    float64
#  2   Low        780 non-null    float64
#  3   Close      780 non-null    float64
#  4   Adj Close  780 non-null    float64
#  5   Volume     780 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 42.7 KB

# %%
#  RSI TESTING LAB

x = tb.RSI(np.array(data_raw['Close'].dropna()))
if(x[-1] < 30):
    print("buy --- RSI LEVEL ::  "+ str(x[-1]))

# %%
main_data = data_raw[400:800]
#stock_check_weekly(main_data)
plt.plot(main_data['Close'])

# %%
# health_checkup of stock
main_data[-680:]

macd,macdsignal,macdhist = tb.MACD(main_data["Close"].dropna())
plt.plot(macd)
plt.plot(macdsignal)

# %% [markdown]
# <h1> TESTING SITE </h1>
# <P>
# features included - > <p>
# 1> RSI CHECK
# 2> MACD-CROSSOVER CHECK
# 3> MOVING AVERAGE CHECK
# </P>
#  # instructions
# firt apply to 1- day trading then to 30-min trading
# multiple time-frames and their relative margin must also be checked

# %%
# included __ 1> macd crossover 2> rsi indicator

# THIS IS  A FUNCTION WITHOUT STOP LOSS111

signal_RSI = 0
signal = 0
share_price = 0
quantity = 0
i = 0
while i< 200:



#------------------
   

    # important case studies 
    #--------------------------------------------------------------
    main_data = data_raw[400: (600+1)]
    #--------------------------------------------
    
    ''' when using 30min time_frame  data_raw = yf.download(tickers=company_name,period = "10d",interval = "30m")  '''





    #--------------------------------------------------------------------------------

    
    macd,macdsignal,macdhist = tb.MACD(main_data["Close"].dropna())
    plt.plot(macd)
    plt.plot(macdsignal)
    df = pd.DataFrame({"macd": macd.dropna(), "macdsignal":macdsignal.dropna()})
    df["boolean"] = df["macd"]>df["macdsignal"]
    data_1 = list(df["macd"].tail(10))
    data_2 = list(df["macdsignal"].tail(10))
    data_3 = list(df["boolean"].tail(10))
    data = list(zip(data_1,data_2,data_3))

    x_RSI = tb.RSI(np.array(data_raw['Close'].dropna()))
    print(x_RSI[-1])
    if(x_RSI[-1] <= 30):  # make it 35
        signal_RSI = 1    # activationg signal
    

    # checking overall profit or loss if shares bought
    if(signal == 1):
        print("net profit/loss \n")
        data_final = (quantity*main_data.iloc[-1]['Close']) - (quantity*share_price) 
        if(data_final>0):
            print("profit %d" ,data_final)
        else:
            print("loss %d" , data_final)
    
        yes_no = input("want to sell the shares \n")
        if(yes_no == '1'):
            signal = 0
            quantity = 0
            share_price = 0
            print("net amount %d", data_final)
            signal_RSI = 0
    




    x = data_3
    #print(data_3)
    if((x[9]> x[8])):
        print("possible uptrend")

       # enter_data(company_name)
        

        
    elif(x[9]<x[8]):
        print("possible downtrend")
    
    elif(x[9] == x[8]):

        data_1 = x[7]
        data_2 = x[8]
        data_3 = x[9]
        series_1 = pd.Series([data_1, data_2,data_3])  #main_series
        # sampler series
        series_2 = pd.Series([True, False, False]) #downtrend
        Series_3 = pd.Series([False,False, False]) #strong_downtrend
        series_4 = pd.Series([False,True, True])  #uptrend
        series_5 = pd.Series([True,True, True]) #strong_uptrend
        if((pd.Series(series_1 == series_4).all() == True) or (pd.Series(series_1 == series_5).all() == True)):
            if((pd.Series(series_1 == series_4).all() == True) ):
                if(signal_RSI == 1):
                    buy_call = input("do you want to buy the stock")
                if(buy_call == '0'):
                    print("Uptrend")
                    data_1 = int(input("enter the quantity"))
                    quantity = data_1
                    share_price =  main_data.iloc[-1]['Close']
                    signal = 1
                    print('%d quantites bought at price %d', data_1,main_data.iloc[-1]['Close'])

                    print("total %d",data_1*main_data.iloc[-1]['Close'])
                


        else:

            print("downtrend")
    i += 1
    print("=====================================================================")
# Out:
# 35.69757136480022
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10684/2087684209.py in <module>
#      93                 if(signal_RSI == 1):
#      94                     buy_call = input("do you want to buy the stock")
# ---> 95                 if(buy_call == '0'):
#      96                     print("Uptrend")
#      97                     data_1 = int(input("enter the quantity"))
#
# NameError: name 'buy_call' is not defined

# %% [markdown]
# <H1>FUNCTION WITH STOP-LOSS </H1>

# %%
# included __ 1> macd crossover 2> rsi indicator

#  STOP LOSS INCLUDED

signal = 0
share_price = 0
quantity = 0
main_data = data_raw
x_RSI = tb.RSI(np.array(data_raw['Close'].dropna()))
while(i< 385):

#------------------
   

    # important case studies 
    #--------------------------------------------------------------
  
    #--------------------------------------------
    
    ''' when using 30min time_frame  data_raw = yf.download(tickers=company_name,period = "10d",interval = "30m")  '''





    #--------------------------------------------------------------------------------

    signal_RSI = 0
    macd,macdsignal,macdhist = tb.MACD(main_data["Close"].dropna())
    plt.plot(macd)
    plt.plot(macdsignal)
    df = pd.DataFrame({"macd": macd.dropna(), "macdsignal":macdsignal.dropna()})
    df["boolean"] = df["macd"]>df["mdacdsignal"]
    data_1 = list(df["macd"].tail(10))
    data_2 = list(df["macdsignal"].tail(10))
    data_3 = list(df["boolean"].tail(10))
    

    x_RSI = tb.RSI(np.array(data_raw['Close'].dropna()))
    print(x_RSI[-1])
    if(x_RSI[384+i] <= 30):
        signal_RSI = 1    # activationg signal
    

    # checking overall profit or loss if shares bought
    if(signal == 1):
        print("net profit/loss \n")
        data_final = (quantity*main_data.iloc[-1]['Close']) - (quantity*share_price) 
        if(data_final>0):
            print("profit %d" ,data_final)
        else:
            print("loss %d" , data_final)
             # stopp loss is inserted here
            if(data_final < -200):
                signal = 0
                quantity =0
                share_price =0
                print('net amount %d', data_final)
                signal_RSI = 0
            
    
        yes_no = input("want to sell the shares \n")
        if(yes_no == '1'):
            signal = 0
            quantity = 0
            share_price = 0
            print("net amount %d", data_final)
            signal_RSI = 0
    




    x = data_3
    #print(data_3)
    if((x[9]> x[8])):
        print("possible uptrend")

       # enter_data(company_name)
        

        
    elif(x[9]<x[8]):
        print("possible downtrend")
    
    elif(x[9] == x[8]):

        data_1 = x[7]
        data_2 = x[8]
        data_3 = x[9]
        series_1 = pd.Series([data_1, data_2,data_3])  #main_series
        # sampler series
        series_2 = pd.Series([True, False, False]) #downtrend
        Series_3 = pd.Series([False,False, False]) #strong_downtrend
        series_4 = pd.Series([False,True, True])  #uptrend
        series_5 = pd.Series([True,True, True]) #strong_uptrend
        if((pd.Series(series_1 == series_4).all() == True) or (pd.Series(series_1 == series_5).all() == True)):
            if((pd.Series(series_1 == series_4).all() == True) ):
               
              
                if(signal_RSI == 1 and signal == 0):
                    print("Uptrend")
                    data_1 = int(input("enter the quantity"))
                    quantity = data_1
                    share_price =  main_data.iloc[-1]['Close']
                    signal = 1
                    print('%d quantites bought at price %d', data_1,main_data.iloc[-1]['Close'])

                    print("total %d",data_1*main_data.iloc[-1]['Close'])
                


        else:

            print("downtrend")
    print("=====================================================================")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\hp\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\hp\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\hp\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mdacdsignal'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# <h1> MAIN FUNCTION </H1>

# %%
data_raw = yf.download(tickers = "TATAELXSI.NS",period = "730d",interval = "1h")
main_data = data_raw
macd,macdsignal,macdhist = tb.MACD(main_data["Close"].dropna())

df = pd.DataFrame({"macd": macd, "macdsignal":macdsignal})
df['x_RSI'] = tb.RSI(main_data["Close"])
df["boolean"] = df["macd"]>df["macdsignal"]
df['Close'] = main_data['Close']
data_1 = list(df["macd"])
data_2 = list(df["macdsignal"])
data_3 = list(df["boolean"])

df.dropna(inplace = True)
data_raw.info()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5087 entries, 2019-08-06 09:15:00+05:30 to 2022-07-15 15:30:00+05:30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5087 non-null   float64
#  1   High       5087 non-null   float64
#  2   Low        5087 non-null   float64
#  3   Close      5087 non-null   float64
#  4   Adj Close  5087 non-null   float64
#  5   Volume     5087 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 278.2 KB

# %%
# WEEKLY DATA FETCH 
data_raw = yf.download(tickers = "HDFC.NS",interval = "1wk")
main_data = data_raw
macd,macdsignal,macdhist = tb.MACD(main_data["Close"].dropna())

df = pd.DataFrame({"macd": macd, "macdsignal":macdsignal})
df['x_RSI'] = tb.RSI(main_data["Close"])
df["boolean"] = df["macd"]>df["macdsignal"]
df['Close'] = main_data['Close']
data_1 = list(df["macd"])
data_2 = list(df["macdsignal"])
data_3 = list(df["boolean"])

df.dropna(inplace = True)
data_raw.info()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1074 entries, 2002-07-01 to 2022-07-15
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1047 non-null   float64
#  1   High       1047 non-null   float64
#  2   Low        1047 non-null   float64
#  3   Close      1047 non-null   float64
#  4   Adj Close  1047 non-null   float64
#  5   Volume     1047 non-null   float64
# dtypes: float64(6)
# memory usage: 91.0 KB

# %%
#total_profit/loss
total = 0





#================================================================

x = list(df['boolean']) # dummy_macd signal
y = list(df['x_RSI'])
price = list(df['Close'])
j = 2
i = 0
quantity = 0
share_price = 0
signal = 0
signal_RSI = 0
data_final_1 = 1
while(i < len(x)-2):

    # if the share has been bought procudure2
    if(signal == 1):
        
        print("net profit/loss \n")
        data_final = (quantity*price[j]) - (quantity*share_price) 
        if(data_final>0):
            print("profit %d" ,data_final)
        else:
            print("loss %d" , data_final)
             # stopp loss is inserted here
            if(data_final_1 < -100):  # stop loss
                total = total + data_final
                signal = 0
                quantity =0
                share_price =0
                print('net amount %d', data_final)
                signal_RSI = 0
        yes_no = input("want to sell the shares \n")
        if(yes_no == '1'):
            total = total + data_final
            signal = 0
            quantity = 0
            share_price = 0
            print("net amount %d", data_final)
            
            signal_RSI = 0


    series_1 = pd.Series([x[j-2],x[j-1],x[j]])
    x_RSI = y[j]
    if(x_RSI <= 40):
        signal_RSI = 1
    series_2 = pd.Series([True, False, False]) #downtrend
    Series_3 = pd.Series([False,False, False]) #strong_downtrend
    series_4 = pd.Series([False,True, True])  #uptrend
    series_5 = pd.Series([True,True, True]) #strong_uptrend
    if((pd.Series(series_1 == series_4).all() == True) or (pd.Series(series_1 == series_5).all() == True)):

        if((pd.Series(series_1 == series_4).all() == True) ):

            if(signal_RSI == 1 and signal == 0):

                print("Uptrend")
                data_1 = int(input("enter the quantity"))
                quantity = data_1
                share_price =  price[j]
                signal = 1
                print('%d quantites bought at price %d',price[j])
                print("total %d",data_1*price[j])
                



    else:





        print("downtrend")
    print("=====================================================================")
    j += 1
    i += 1
# Out:
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# Uptrend
# %d quantites bought at price %d 612.7999877929688
# total %d 6127.9998779296875
# ...
# net profit/loss
#
# loss %d -25.999755859375
# ...
# net profit/loss
#
# profit %d 50.4998779296875
# ...
# net profit/loss
#
# profit %d 117.0001220703125
# net amount %d 117.0001220703125
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# Uptrend
# %d quantites bought at price %d 618.4000244140625
# total %d 6184.000244140625
# ...
# net profit/loss
#
# profit %d 50.0
# ...
# net profit/loss
#
# profit %d 180.999755859375
# ...
# net profit/loss
#
# profit %d 151.99951171875
# ...
# net profit/loss
#
# profit %d 300.999755859375
# net amount %d 300.999755859375
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...
# downtrend
# ...

# %% [markdown]
# <H1>WEEKLY ONLY RSI BASESD SYSTEM </h1>

# %%
#total_profit/loss
total = 0





#================================================================

x = list(df['boolean']) # dummy_macd signal
y = list(df['x_RSI'])
price = list(df['Close'])
j = 2
i = 0
quantity = 0
share_price = 0
signal = 0
signal_RSI = 0
data_final_1 = 1
while(i < len(x)-2):

    # if the share has been bought procudure2
    if(signal == 1):
        
        print("net profit/loss \n")
        data_final = (quantity*price[j]) - (quantity*share_price) 
        if(data_final>0):
            print("profit %d" ,data_final)
        else:
            print("loss %d" , data_final)
             # stopp loss is inserted here
            if(data_final_1 < -100):  # stop loss
                total = total + data_final
                signal = 0
                quantity =0
                share_price =0
                print('net amount %d', data_final)
                signal_RSI = 0
        yes_no = input("want to sell the shares \n")
        if(yes_no == '1'):
            total = total + data_final
            signal = 0
            quantity = 0
            share_price = 0
            print("net amount %d", data_final)
            
            signal_RSI = 0


    series_1 = pd.Series([x[j-2],x[j-1],x[j]])
    x_RSI = y[j]
    if(x_RSI <= 30):
        signal_RSI = 1
    series_2 = pd.Series([True, False, False]) #downtrend
    Series_3 = pd.Series([False,False, False]) #strong_downtrend
    series_4 = pd.Series([False,True, True])  #uptrend
    series_5 = pd.Series([True,True, True]) #strong_uptrend
    if(signal_RSI == 1 and signal == 0):


        print("Uptrend")
        data_1 = int(input("enter the quantity"))
        quantity = data_1
        share_price =  price[j]
        signal = 1
        print('%d quantites bought at price %d',price[j])
        print("total %d",data_1*price[j])
                



    else:





        print("downtrend")
    print("=====================================================================")
    j += 1
    i += 1

# %%
total  # total_amount earnes or 
x= 197945+total-500  #178963

x
# Out:
# 197945.5128173828
